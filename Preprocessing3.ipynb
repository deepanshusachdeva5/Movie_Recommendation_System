# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # getting data from wiki

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"

# %%
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 262  DECEMBER         25             Holmes & Watson
# 263  DECEMBER         25                        Vice
# 264  DECEMBER         25         On the Basis of Sex
# 265  DECEMBER         25                   Destroyer
# 266  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 262       Columbia Pictures / Gary Sanchez Productions
# 263          Annapurna Pictures / Plan B Entertainment
# 264                                     Focus Features
# 265                                 Annapurna Pictures
# 266                                            Netflix
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Lauren Wolkstein (director); Christopher Radcl...    [3]
# 2    Simon West (director); Duncan Falconer, Warren...    [4]
# 3    Warwick Thornton (director); David Tranter, St...    [5]
# 4    Jaume Collet-Serra (director); Byron Willinger...    [6]
# ..                                                 ...    ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...  [162]
# 263  Adam McKay (director/screenplay); Christian Ba...  [136]
# 264  Mimi Leder (director); Daniel Stiepleman (scre...  [223]
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...  [255]
# 266  David Slade (director); Charlie Brooker (scree...  [256]
#
# [267 rows x 6 columns]

# %%
# conda install tmdv3api

# %%
from tmdbv3api import TMDb

# %%
import json
import requests
tmdb = TMDb()
tmdb.api_key = '8a4de863cc48d466d9484d3ad930a045'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()

# %%
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str= " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 262  DECEMBER         25             Holmes & Watson
# 263  DECEMBER         25                        Vice
# 264  DECEMBER         25         On the Basis of Sex
# 265  DECEMBER         25                   Destroyer
# 266  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 262       Columbia Pictures / Gary Sanchez Productions
# 263          Annapurna Pictures / Plan B Entertainment
# 264                                     Focus Features
# 265                                 Annapurna Pictures
# 266                                            Netflix
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Lauren Wolkstein (director); Christopher Radcl...    [3]
# 2    Simon West (director); Duncan Falconer, Warren...    [4]
# 3    Warwick Thornton (director); David Tranter, St...    [5]
# 4    Jaume Collet-Serra (director); Byron Willinger...    [6]
# ..                                                 ...    ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...  [162]
# 263  Adam McKay (director/screenplay); Christian Ba...  [136]
# 264  Mimi Leder (director); Daniel Stiepleman (scre...  [223]
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...  [255]
# 266  David Slade (director); Charlie Brooker (scree...  [256]
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                                    Action Thriller
# ..                                               ...
# 262                   Mystery Adventure Comedy Crime
# 263        Thriller Science Fiction Action Adventure
# 264                                    Drama History
# 265                      Thriller Crime Drama Action
# 266  Science Fiction Mystery Drama Thriller TV Movie
#
# [267 rows x 7 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 266  David Slade (director); Charlie Brooker (scree...
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                                    Action Thriller
# ..                                               ...
# 262                   Mystery Adventure Comedy Crime
# 263        Thriller Science Fiction Action Adventure
# 264                                    Drama History
# 265                      Thriller Crime Drama Action
# 266  Science Fiction Mystery Drama Thriller TV Movie
#
# [267 rows x 3 columns]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-18-4838efec492a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 266  David Slade (director); Charlie Brooker (scree...
#
#                                               genres       director_name
# 0                            Horror Mystery Thriller        Adam Robitel
# 1                                     Thriller Drama    Lauren Wolkstein
# 2                                    Action Thriller          Simon West
# 3                              Drama History Western    Warwick Thornton
# 4                                    Action Thriller  Jaume Collet-Serra
# ..                                               ...                 ...
# 262                   Mystery Adventure Comedy Crime          Etan Cohen
# 263        Thriller Science Fiction Action Adventure          Adam McKay
# 264                                    Drama History          Mimi Leder
# 265                      Thriller Crime Drama Action        Karyn Kusama
# 266  Science Fiction Mystery Drama Thriller TV Movie         David Slade
#
# [267 rows x 4 columns]

# %%
def get_actor1(x):
    return ((x.split('(screenplay); ')[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x:get_actor1(x))
# Out:
# <ipython-input-21-a63d8c1b50b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x:get_actor1(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 266  David Slade (director); Charlie Brooker (scree...
#
#                                               genres       director_name  \
# 0                            Horror Mystery Thriller        Adam Robitel
# 1                                     Thriller Drama    Lauren Wolkstein
# 2                                    Action Thriller          Simon West
# 3                              Drama History Western    Warwick Thornton
# 4                                    Action Thriller  Jaume Collet-Serra
# ..                                               ...                 ...
# 262                   Mystery Adventure Comedy Crime          Etan Cohen
# 263        Thriller Science Fiction Action Adventure          Adam McKay
# 264                                    Drama History          Mimi Leder
# 265                      Thriller Crime Drama Action        Karyn Kusama
# 266  Science Fiction Mystery Drama Thriller TV Movie         David Slade
#
#                                           actor_1_name
# 0                                            Lin Shaye
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2                                       Dominic Cooper
# 3                                          Bryan Brown
# 4                                          Liam Neeson
# ..                                                 ...
# 262     Etan Cohen (director/screenplay); Will Ferrell
# 263   Adam McKay (director/screenplay); Christian Bale
# 264                                     Felicity Jones
# 265                                      Nicole Kidman
# 266                                    Fionn Whitehead
#
# [267 rows x 5 columns]

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x:get_actor2(x))
# Out:
# <ipython-input-24-7f3d498005af>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x:get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres       director_name  \
# 0  Horror Mystery Thriller        Adam Robitel
# 1           Thriller Drama    Lauren Wolkstein
# 2          Action Thriller          Simon West
# 3    Drama History Western    Warwick Thornton
# 4          Action Thriller  Jaume Collet-Serra
#
#                                         actor_1_name            actor_2_name  \
# 0                                          Lin Shaye           Angus Sampson
# 1  Lauren Wolkstein (director); Christopher Radcl...  James Freedson-Jackson
# 2                                     Dominic Cooper          Austin Stowell
# 3                                        Bryan Brown               Sam Neill
# 4                                        Liam Neeson            Vera Farmiga
#
#      actor_3_name
# 0  Leigh Whannell
# 1   Emily Althaus
# 2      Gemma Chan
# 3             NaN
# 4  Patrick Wilson

# %%
df_2018=df_2018.rename(columns={'Title':'movie_title'})

# %%
newdf_2018 = df_2018[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
newdf_2018
# Out:
#           director_name                                       actor_1_name  \
# 0          Adam Robitel                                          Lin Shaye
# 1      Lauren Wolkstein  Lauren Wolkstein (director); Christopher Radcl...
# 2            Simon West                                     Dominic Cooper
# 3      Warwick Thornton                                        Bryan Brown
# 4    Jaume Collet-Serra                                        Liam Neeson
# ..                  ...                                                ...
# 262          Etan Cohen     Etan Cohen (director/screenplay); Will Ferrell
# 263          Adam McKay   Adam McKay (director/screenplay); Christian Bale
# 264          Mimi Leder                                     Felicity Jones
# 265        Karyn Kusama                                      Nicole Kidman
# 266         David Slade                                    Fionn Whitehead
#
#                actor_2_name    actor_3_name  \
# 0             Angus Sampson  Leigh Whannell
# 1    James Freedson-Jackson   Emily Althaus
# 2            Austin Stowell      Gemma Chan
# 3                 Sam Neill             NaN
# 4              Vera Farmiga  Patrick Wilson
# ..                      ...             ...
# 262          John C. Reilly    Rebecca Hall
# 263               Amy Adams    Steve Carell
# 264            Armie Hammer  Justin Theroux
# 265          Sebastian Stan    Toby Kebbell
# 266            Will Poulter   Asim Chaudhry
#
#                                               genres  \
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                                    Action Thriller
# ..                                               ...
# 262                   Mystery Adventure Comedy Crime
# 263        Thriller Science Fiction Action Adventure
# 264                                    Drama History
# 265                      Thriller Crime Drama Action
# 266  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
# [267 rows x 6 columns]

# %%
newdf_2018['actor_2_name'] = newdf_2018['actor_2_name'].replace(np.nan, 'unknown')
newdf_2018['actor_3_name'] = newdf_2018['actor_3_name'].replace(np.nan, 'unknown')
# Out:
# <ipython-input-33-78de02cf6009>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf_2018['actor_2_name'] = newdf_2018['actor_2_name'].replace(np.nan, 'unknown')
# <ipython-input-33-78de02cf6009>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf_2018['actor_3_name'] = newdf_2018['actor_3_name'].replace(np.nan, 'unknown')

# %%
newdf_2018['movie_title'] = newdf_2018['movie_title'].str.lower()
# Out:
# <ipython-input-38-1068cfae433c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf_2018['movie_title'] = newdf_2018['movie_title'].str.lower()

# %%
newdf_2018['comb'] = newdf_2018['actor_1_name'] + ' ' +newdf_2018['actor_2_name'] + ' ' + newdf_2018['actor_3_name'] + ' '+newdf_2018['director_name'] + ' '+newdf_2018['genres']

# %%
newdf_2018
# Out:
#           director_name                                       actor_1_name  \
# 0          Adam Robitel                                          Lin Shaye
# 1      Lauren Wolkstein  Lauren Wolkstein (director); Christopher Radcl...
# 2            Simon West                                     Dominic Cooper
# 3      Warwick Thornton                                        Bryan Brown
# 4    Jaume Collet-Serra                                        Liam Neeson
# ..                  ...                                                ...
# 262          Etan Cohen     Etan Cohen (director/screenplay); Will Ferrell
# 263          Adam McKay   Adam McKay (director/screenplay); Christian Bale
# 264          Mimi Leder                                     Felicity Jones
# 265        Karyn Kusama                                      Nicole Kidman
# 266         David Slade                                    Fionn Whitehead
#
#                actor_2_name    actor_3_name  \
# 0             Angus Sampson  Leigh Whannell
# 1    James Freedson-Jackson   Emily Althaus
# 2            Austin Stowell      Gemma Chan
# 3                 Sam Neill         unknown
# 4              Vera Farmiga  Patrick Wilson
# ..                      ...             ...
# 262          John C. Reilly    Rebecca Hall
# 263               Amy Adams    Steve Carell
# 264            Armie Hammer  Justin Theroux
# 265          Sebastian Stan    Toby Kebbell
# 266            Will Poulter   Asim Chaudhry
#
#                                               genres  \
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                                    Action Thriller
# ..                                               ...
# 262                   Mystery Adventure Comedy Crime
# 263        Thriller Science Fiction Action Adventure
# 264                                    Drama History
# 265                      Thriller Crime Drama Action
# 266  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 262             holmes & watson
# 263                        vice
# 264         on the basis of sex
# 265                   destroyer
# 266  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Felicity Jones Armie Hammer Justin Theroux Mim...
# 265  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 266  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [267 rows x 7 columns]

# %% [markdown]
# ## 2019 movies

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df1
# Out:
#      Opening  Opening.1                                       Title  \
# 0    JANUARY          4                                 Escape Room
# 1    JANUARY          4                                  Rust Creek
# 2    JANUARY          4                            American Hangman
# 3    JANUARY         11                            A Dog's Way Home
# 4    JANUARY         11                                  The Upside
# 5    JANUARY         11                                    Replicas
# 6    JANUARY         15                              After Darkness
# 7    JANUARY         18                                       Glass
# 8    JANUARY         18                                       Close
# 9    JANUARY         18               The Standoff at Sparrow Creek
# 10   JANUARY         24                              The Final Wish
# 11   JANUARY         25                   The Kid Who Would Be King
# 12   JANUARY         25                                    Serenity
# 13   JANUARY         25                                 I Am Mother
# 14   JANUARY         26                           The Vast of Night
# 15  FEBRUARY          1                                   Miss Bala
# 16  FEBRUARY          1                              Velvet Buzzsaw
# 17  FEBRUARY          1                                    Piercing
# 18  FEBRUARY          8           The Lego Movie 2: The Second Part
# 19  FEBRUARY          8                               What Men Want
# 20  FEBRUARY          8                                Cold Pursuit
# 21  FEBRUARY          8                            High Flying Bird
# 22  FEBRUARY          8                                 The Prodigy
# 23  FEBRUARY         13                           Isn't It Romantic
# 24  FEBRUARY         13                          Happy Death Day 2U
# 25  FEBRUARY         14                         Alita: Battle Angel
# 26  FEBRUARY         22  How to Train Your Dragon: The Hidden World
# 27  FEBRUARY         22                     Fighting with My Family
# 28     MARCH          1        Tyler Perry's A Madea Family Funeral
# 29     MARCH          1                                       Greta
# 30     MARCH          6                             Triple Frontier
# 31     MARCH          8                              Captain Marvel
# 32     MARCH          8                                     The Kid
# 33     MARCH         15                                 Wonder Park
# 34     MARCH         15                               Captive State
# 35     MARCH         15         Nancy Drew and the Hidden Staircase
# 36     MARCH         15                               The Aftermath
# 37     MARCH         15                             Five Feet Apart
# 38     MARCH         15                              The Highwaymen
# 39     MARCH         15                                      Red 11
# 40     MARCH         15                              Never Grow Old
# 41     MARCH         19                               Triple Threat
# 42     MARCH         22                                          Us
# 43     MARCH         22                                Hotel Mumbai
# 44     MARCH         22                                    The Dirt
# 45     MARCH         22                     Dragged Across Concrete
# 46     MARCH         29                                       Dumbo
# 47     MARCH         29                               The Beach Bum
# 48     MARCH         29                                   Unplanned
#
#                                    Production company  \
# 0                                   Columbia Pictures
# 1                                           IFC Films
# 2                         Hangman Justice Productions
# 3                                   Columbia Pictures
# 4                                   STX Entertainment
# 5                               Entertainment Studios
# 6                      Grindstone Entertainment Group
# 7   Universal Pictures / Buena Vista International...
# 8                                             Netflix
# 9                                           Cinestate
# 10  BondIt Media Capital / Global Renaissance Ente...
# 11  20th Century Fox / TSG Entertainment / Working...
# 12        Aviron Pictures / Global Road Entertainment
# 13                                            Netflix
# 14                                         GED Cinema
# 15                                  Columbia Pictures
# 16                                            Netflix
# 17                                 Universal Pictures
# 18     Warner Bros. Pictures / Warner Animation Group
# 19        Paramount Players / Will Packer Productions
# 20                 Summit Entertainment / StudioCanal
# 21                            Netflix / Extension 765
# 22                         Orion Pictures / XYZ Films
# 23  Warner Bros. Pictures / New Line Cinema / Netf...
# 24         Universal Pictures / Blumhouse Productions
# 25  20th Century Fox / Lightstorm Entertainment / ...
# 26          Universal Pictures / DreamWorks Animation
# 27                                Metro-Goldwyn-Mayer
# 28                                          Lionsgate
# 29                                     Focus Features
# 30                                            Netflix
# 31                                     Marvel Studios
# 32                                    Lionsgate Films
# 33  Paramount Pictures / Paramount Animation / Nic...
# 34                 Focus Features / Participant Media
# 35     Warner Bros. Pictures / A Very Good Production
# 36                           Fox Searchlight Pictures
# 37                              Lionsgate / CBS Films
# 38                                            Netflix
# 39                                           Double R
# 40                       Saban Films / Canal+ / Ciné+
# 41   WWE Studios / TF1 Séries Films / Ingenious Media
# 42  Universal Pictures / Monkeypaw Productions / P...
# 43             Thunder Road Pictures / Arclight Films
# 44                                            Netflix
# 45                                          Cinestate
# 46                               Walt Disney Pictures
# 47                                               Neon
# 48                                          Pure Flix
#
#                                         Cast and crew     Ref.
# 0   Adam Robitel (director); Bragi F. Schut, Maria...      [2]
#    Opening  Opening.1                        Title  \
# 0    APRIL          5                      Shazam!
# 1    APRIL          5                 Pet Sematary
# 2    APRIL          5          The Best of Enemies
# 3    APRIL          5                    High Life
# 4    APRIL          5  The Haunting of Sharon Tate
# ..     ...        ...                          ...
# 61    JUNE         21                 Child's Play
# 62    JUNE         26         Annabelle Comes Home
# 63    JUNE         28                    Yesterday
# 64    JUNE         28                      Ophelia
# 65    JUNE         28            Killers Anonymous
#
#                                    Production company  \
# 0   Warner Bros. Pictures / New Line Cinema / DC F...
# 1                                  Paramount Pictures
# 2                                   STX Entertainment
# 3                   A24 / Arte / ZDF / Canal+ / Ciné+
# 4                      Saban Films / Voltage Pictures
# ..                                                ...
# 61                     Orion Pictures / Bron Creative
# 62            Warner Bros. Pictures / New Line Cinema
# 63  Universal Pictures / Perfect World Pictures / ...
# 64                                          IFC Films
# 65                                          Lionsgate
#
#                                         Cast and crew   Ref.
# 0   David F. Sandberg (director); Henry Gayden (sc...   [51]
# 1   Kevin Kolsch, Dennis Widmyer (directors); Jeff...   [52]
# 2   Robin Bissell (director/screenplay); Taraji P....   [53]
# 3   Claire Denis (director/screenplay); Jean-Pol F...   [54]
# 4   Daniel Farrands (director/screenplay); Hilary ...   [55]
# ..                                                ...    ...
# 61  Lars Klevberg (director); Tyler Burton Smith (...  [110]
# 62  Gary Dauberman (director/screenplay); Mckenna ...  [111]
# 63  Danny Boyle (director); Richard Curtis (screen...  [112]
# 64  Claire McCarthy (director); Semi Chellas (scre...  [113]
# 65  Martin Owen (director/screenplay); Elizabeth M...  [114]
#
# [66 rows x 6 columns]

# %%
df3
# Out:
#       Opening  Opening.1                                  Title  \
# 0        JULY          2              Spider-Man: Far From Home
# 1        JULY          2            Escape Plan: The Extractors
# 2        JULY          3                              Midsommar
# 3        JULY         12                                 Stuber
# 4        JULY         12                                  Crawl
# 5        JULY         12                            Point Blank
# 6        JULY         12                           The Farewell
# 7        JULY         12                                Darlin'
# 8        JULY         19                          The Lion King
# 9        JULY         26          Once Upon a Time in Hollywood
# 10       JULY         26                                   Skin
# 11       JULY         31              The Red Sea Diving Resort
# 12     AUGUST          2  Fast & Furious Presents: Hobbs & Shaw
# 13     AUGUST          2                      A Score to Settle
# 14     AUGUST          2                          The Operative
# 15     AUGUST          9         Dora and the Lost City of Gold
# 16     AUGUST          9                            The Kitchen
# 17     AUGUST          9          The Art of Racing in the Rain
# 18     AUGUST          9      Scary Stories to Tell in the Dark
# 19     AUGUST          9               The Peanut Butter Falcon
# 20     AUGUST          9                      After the Wedding
# 21     AUGUST          9                       Light of My Life
# 22     AUGUST         14                The Angry Birds Movie 2
# 23     AUGUST         16                              Good Boys
# 24     AUGUST         16                   Blinded by the Light
# 25     AUGUST         16             Where'd You Go, Bernadette
# 26     AUGUST         16                47 Meters Down: Uncaged
# 27     AUGUST         16                                   Gwen
# 28     AUGUST         21                           Ready or Not
# 29     AUGUST         23                       Angel Has Fallen
# 30     AUGUST         23               Brittany Runs a Marathon
# 31     AUGUST         23                              Overcomer
# 32     AUGUST         23                         Jacob's Ladder
# 45  Nzingha Stewart (director); Sam Wolfson (scree...  [159]
# 46  Lars Klevberg (director); Blair Butler (screen...  [160]
# 47  James Gray (director/screenplay); Ethan Gross ...  [132]
# 48  Michael Engler (director); Julian Fellowes (sc...  [112]
# 49  Adrian Grunberg (director); Sylvester Stallone...  [161]
# 50  Henry Jacobson (director); Avra Fox-Lerne, Hen...  [162]
# 51  Jason Cabell (director/screenplay); Nicolas Ca...  [163]
# 52  Brad Anderson (director); Alan B. McElroy (scr...    NaN
# 53  Bree Mills (director); Angela White, Seth Gamb...  [164]
# 54  Jill Culton (director/screenplay); Todd Wilder...  [165]
# 55  Steven Soderbergh (director); Scott Z. Burns (...  [166]
# 56  Rupert Goold (director); Tom Edge (screenplay)...  [167]
# 57  Franck Khalfoun (director); David Coggeshall, ...  [168]

# %%
df4
# Out:
#      Opening  Opening.1                Title  \
# 0    OCTOBER          4                Joker
# 1    OCTOBER          4      Lucy in the Sky
# 2    OCTOBER          4  Dolemite Is My Name
# 3    OCTOBER          4    In the Tall Grass
# 4    OCTOBER          4             Low Tide
# ..       ...        ...                  ...
# 65  DECEMBER         25         Little Women
# 66  DECEMBER         25                 1917
# 67  DECEMBER         25           Just Mercy
# 68  DECEMBER         27             Clemency
# 69  DECEMBER         27           Apparition
#
#                                    Production company  \
# 0   Warner Bros. Pictures / Village Roadshow Pictu...
# 1                            Fox Searchlight Pictures
# 2                                             Netflix
# 3                                             Netflix
# 4                                A24 / DirecTV Cinema
# ..                                                ...
# 65            Columbia Pictures / Regency Enterprises
# 66  Universal Pictures / DreamWorks Pictures / Ent...
# 67          Warner Bros. Pictures / Participant Media
# 68                                               Neon
# 69                                  Vertical Pictures
#
#                                         Cast and crew   Ref.
# 0   Todd Phillips (director/screenplay); Scott Sil...  [169]
# 1   Noah Hawley (director/screenplay); Brian C. Br...  [170]
# 2   Craig Brewer (director); Scott Alexander and L...  [166]
# 3   Vincenzo Natali (director/screenplay); Patrick...    NaN
# 4   Kevin McMullin (director/screenplay); Keean Jo...  [171]
# ..                                                ...    ...
# 65  Greta Gerwig (director/screenplay); Saoirse Ro...  [223]
# 66  Sam Mendes (director/screenplay); Krysty Wilso...  [224]
# 67  Destin Daniel Cretton (director/screenplay), A...  [225]
# 68  Chinonye Chukwu (director/screenplay); Alfre W...  [226]
# 69  Waymon Boone (director/screenplay); Mena Suvar...  [227]
#
# [70 rows x 6 columns]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                 Title                                      Cast and crew  \
# 0         Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1          Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2    American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3    A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4          The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                ...                                                ...
# 238      Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239              1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240        Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241          Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
# 242        Apparition  Waymon Boone (director/screenplay); Mena Suvar...
#
#                                        genres
# 0    Thriller Action Mystery Adventure Horror
# 1                              Thriller Drama
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 238                             Drama Romance
# 239                          War Drama Action
# 240                                     Drama
# 241                                     Drama
# 242                           Horror Thriller
#
# [243 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(' (director)')[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x:get_director(str(x)))
# Out:
# <ipython-input-53-6edb6287edca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x:get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split('screenplay); ')[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x:get_actor1(x))
# Out:
# <ipython-input-55-88445e662983>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x:get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x:get_actor2(x))
# Out:
# <ipython-input-57-0a32e5473fb7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x:get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", "))<3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019
# Out:
#                 Title                                      Cast and crew  \
# 0         Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1          Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2    American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3    A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4          The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                ...                                                ...
# 238      Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239              1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240        Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241          Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
# 242        Apparition  Waymon Boone (director/screenplay); Mena Suvar...
#
#                                        genres          director_name  \
# 0    Thriller Action Mystery Adventure Horror           Adam Robitel
# 1                              Thriller Drama            Jen McGowan
# 2                                    Thriller      Wilson Coneybeare
# 3                      Drama Adventure Family   Charles Martin Smith
# 4                                Comedy Drama            Neil Burger
# ..                                        ...                    ...
# 238                             Drama Romance           Greta Gerwig
# 239                          War Drama Action             Sam Mendes
# 240                                     Drama  Destin Daniel Cretton
# 241                                     Drama        Chinonye Chukwu
# 242                           Horror Thriller           Waymon Boone
#
#             actor_1_name          actor_2_name      actor_3_name
# 0         Taylor Russell          Logan Miller  Deborah Ann Woll
# 1      Hermione Corfield           Jay Paulson      Sean O'Bryan
# 2      Donald Sutherland    Vincent Kartheiser     Oliver Dennis
# 3    Bryce Dallas Howard    Edward James Olmos   Alexandra Shipp
# 4         Bryan Cranston            Kevin Hart     Nicole Kidman
# ..                   ...                   ...               ...
# 238        Saoirse Ronan           Emma Watson     Florence Pugh
# 239        George MacKay  Dean-Charles Chapman       Mark Strong
# 240    Michael B. Jordan            Jamie Foxx       Brie Larson
# 241        Alfre Woodard        Wendell Pierce       Aldis Hodge
# 242          Mena Suvari          Kevin Pollak               NaN
#
# [243 rows x 7 columns]

# %%
df_2019 = df_2019.rename(columns ={'Title':'movie_title'})

# %%
newdf_2019 = df_2019[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
newdf_2019['actor_2_name'] = newdf_2019['actor_2_name'].replace(np.NaN,'unknown')
newdf_2019['actor_3_name'] = newdf_2019['actor_3_name'].replace(np.NaN,'unknown')
# Out:
# <ipython-input-64-ea5550deaa08>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf_2019['actor_2_name'] = newdf_2019['actor_2_name'].replace(np.NaN,'unknown')
# <ipython-input-64-ea5550deaa08>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf_2019['actor_3_name'] = newdf_2019['actor_3_name'].replace(np.NaN,'unknown')

# %%
newdf_2019['movie_title'] = newdf_2019['movie_title'].str.lower()
# Out:
# <ipython-input-65-499bd41e3a10>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf_2019['movie_title'] = newdf_2019['movie_title'].str.lower()

# %%
newdf_2019['comb'] = newdf_2019['actor_1_name'] + ' ' + newdf_2019['actor_2_name'] + ' '+ newdf_2019['actor_3_name'] + ' '+ newdf_2019['director_name'] +' ' + newdf_2019['genres']

# %%
newdf_2019
# Out:
#              director_name         actor_1_name          actor_2_name  \
# 0             Adam Robitel       Taylor Russell          Logan Miller
# 1              Jen McGowan    Hermione Corfield           Jay Paulson
# 2        Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3     Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4              Neil Burger       Bryan Cranston            Kevin Hart
# ..                     ...                  ...                   ...
# 238           Greta Gerwig        Saoirse Ronan           Emma Watson
# 239             Sam Mendes        George MacKay  Dean-Charles Chapman
# 240  Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 241        Chinonye Chukwu        Alfre Woodard        Wendell Pierce
# 242           Waymon Boone          Mena Suvari          Kevin Pollak
#
#          actor_3_name                                    genres  \
# 0    Deborah Ann Woll  Thriller Action Mystery Adventure Horror
# 1        Sean O'Bryan                            Thriller Drama
# 2       Oliver Dennis                                  Thriller
# 3     Alexandra Shipp                    Drama Adventure Family
# 4       Nicole Kidman                              Comedy Drama
# ..                ...                                       ...
# 238     Florence Pugh                             Drama Romance
# 239       Mark Strong                          War Drama Action
# 240       Brie Larson                                     Drama
# 241       Aldis Hodge                                     Drama
# 242           unknown                           Horror Thriller
#
#           movie_title                                               comb
# 0         escape room  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1          rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2    american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3    a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4          the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                ...                                                ...
# 238      little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 239              1917  George MacKay Dean-Charles Chapman Mark Strong...
# 240        just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 241          clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 242        apparition  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [243 rows x 7 columns]

# %%
my_df = newdf_2018.append(newdf_2019,ignore_index=True)

# %%
my_df
# Out:
#              director_name                                       actor_1_name  \
# 0             Adam Robitel                                          Lin Shaye
# 1         Lauren Wolkstein  Lauren Wolkstein (director); Christopher Radcl...
# 2               Simon West                                     Dominic Cooper
# 3         Warwick Thornton                                        Bryan Brown
# 4       Jaume Collet-Serra                                        Liam Neeson
# ..                     ...                                                ...
# 505           Greta Gerwig                                      Saoirse Ronan
# 506             Sam Mendes                                      George MacKay
# 507  Destin Daniel Cretton                                  Michael B. Jordan
# 508        Chinonye Chukwu                                      Alfre Woodard
# 509           Waymon Boone                                        Mena Suvari
#
#                actor_2_name    actor_3_name                   genres  \
# 0             Angus Sampson  Leigh Whannell  Horror Mystery Thriller
# 1    James Freedson-Jackson   Emily Althaus           Thriller Drama
# 2            Austin Stowell      Gemma Chan          Action Thriller
# 3                 Sam Neill         unknown    Drama History Western
# 4              Vera Farmiga  Patrick Wilson          Action Thriller
# ..                      ...             ...                      ...
# 505             Emma Watson   Florence Pugh            Drama Romance
# 506    Dean-Charles Chapman     Mark Strong         War Drama Action
# 507              Jamie Foxx     Brie Larson                    Drama
# 508          Wendell Pierce     Aldis Hodge                    Drama
# 509            Kevin Pollak         unknown          Horror Thriller
#
#                  movie_title  \
# 0    insidious: the last key
# 1           the strange ones
# 2                   stratton
# 3              sweet country
# 4               the commuter
# ..                       ...
# 505             little women
# 506                     1917
# 507               just mercy
# 508                 clemency
# 509               apparition
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 505  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 506  George MacKay Dean-Charles Chapman Mark Strong...
# 507  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 508  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 509  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [510 rows x 7 columns]

# %%
old_df = pd.read_csv('preprocessed_data2.csv')

# %%
old_df.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5869           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5870             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5871  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5872        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 5873           Waymon Boone        Mena Suvari          Kevin Pollak
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5869         Florence Pugh                    Drama Romance
# 5870           Mark Strong                 War Drama Action
# 5871           Brie Larson                            Drama
# 5872           Aldis Hodge                            Drama
# 5873               unknown                  Horror Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5869                                       little women
# 5870                                               1917
# 5871                                         just mercy
# 5872                                           clemency
# 5873                                         apparition
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5869  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5870  George MacKay Dean-Charles Chapman Mark Strong...
# 5871  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5872  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 5873  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [5874 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           5
# movie_title      0
# comb             5
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index = False)
